# %%
# Importing the usefull library for the K-mean clustering

import pandas as pd # pandas
import seaborn as sns # seaborn
import matplotlib.pyplot as plt # matplotlib
import numpy as np # numpy
# show the plot next to the code line not in the new window so the %matplotlib used
# %matplotlib inline
